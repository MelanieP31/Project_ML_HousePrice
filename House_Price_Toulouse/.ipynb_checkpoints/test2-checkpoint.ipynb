# %% [markdown]
# <h1 align=center> House and Appartement pricing in Haute_Garonne (31) </h1>

# %% [markdown]
# The goal is to fecth data from data.gouv.fr of the house sell in the department 31 for finding some patterns and deploy a model to predict the value of an house or appartment.
# Source : https://files.data.gouv.fr/geo-dvf/latest/csv/
#
# * First step : Fetch all the necessary data
# * Second step : simplify, by droping a lot of unnecessary data (we want an estimation of the price : enter a few data)
# * Third : Cleaning
# * Fourth : Generalized : drop outliers
# * Fith : Exploratory analysis : is it actually possible with the data we have ?
#
# * Sixth : Model ?

# %%
import os
import uuid
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data collection

# %%
def get_csv(url,download_folder) : 
    response = requests.get(url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    csv_links = soup.find_all('a', href=True)
    csv_links = [link for link in csv_links if link['href'].endswith('.csv')]
    
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)
              
    for link in csv_links:
        file_url = urljoin(url, link['href'])
        original_file_name = os.path.basename(link['href'])
        unique_file_name = f"{uuid.uuid4()}_{original_file_name}"
        file_path = os.path.join(download_folder, unique_file_name)
        
        try :    
            file_response = requests.get(file_url)
            file_response.raise_for_status()
    
            with open(file_path, 'wb') as file:
                file.write(file_response.content)
        except requests.exceptions.RequestException as e:
            print(f'Erreur lors du téléchargement de {unique_file_name}:{e}')
    
    print('Téléchargement terminé pour URL:.',url)

# %%
download_folder = r'C:\Users\melan\Desktop\DeveloppementInfo\Portfolio\ProjectsData\House_Price_Toulouse\CSV'

# %%
urls = ['https://files.data.gouv.fr/geo-dvf/latest/csv/2023/communes/31/',
    'https://files.data.gouv.fr/geo-dvf/latest/csv/2022/communes/31/']

# %%
for url in urls:
    get_csv(url, download_folder)
# Out:
# Téléchargement terminé pour URL:. https://files.data.gouv.fr/geo-dvf/latest/csv/2023/communes/31/
# Téléchargement terminé pour URL:. https://files.data.gouv.fr/geo-dvf/latest/csv/2022/communes/31/

# %%
dfs = []
for file_name in os.listdir(download_folder):
    if file_name.endswith('.csv'):
        file_path = os.path.join(download_folder, file_name)
        # Lire chaque fichier CSV et l'ajouter à la liste des DataFrames
        df = pd.read_csv(file_path)
        dfs.append(df)
        
concatenated_df = pd.concat(dfs, ignore_index=True)
output_file = os.path.join(download_folder, 'concatenated.csv')
concatenated_df.to_csv(output_file, index=False)

print(f'Tous les fichiers CSV ont été concaténés en : {output_file}')
# Out:
# Tous les fichiers CSV ont été concaténés en : C:\Users\melan\Desktop\DeveloppementInfo\Portfolio\ProjectsData\House_Price_Toulouse\CSV\concatenated.csv

# %% [markdown]
# ## simplification

# %%
df = pd.read_csv(os.path.join(download_folder, 'concatenated.csv'))

# %%
df
# Out:
#         id_mutation date_mutation  numero_disposition nature_mutation  \
# 0       2022-450002    2022-01-13                   1           Vente
# 1       2022-450002    2022-01-13                   1           Vente
# 2       2022-451293    2022-02-01                   1           Vente
# 3       2022-451293    2022-02-01                   1           Vente
# 4       2022-451293    2022-02-01                   1           Vente
# ...             ...           ...                 ...             ...
# 170344  2023-392838    2023-11-02                   1           Vente
# 170345  2023-392838    2023-11-02                   1           Vente
# 170346  2023-392922    2023-12-21                   1           Vente
# 170347  2023-392922    2023-12-21                   1           Vente
# 170348  2023-392922    2023-12-21                   1           Vente
#
#         valeur_fonciere  adresse_numero adresse_suffixe adresse_nom_voie  \
# 0              315000.0            67.0             NaN  CHE LE CARRETAL
# 1              315000.0             NaN             NaN       LE VILLAGE
# 2              217477.8             NaN             NaN       BORDENEUVE
# 3              217477.8             NaN             NaN       CHARROULES
# 4              217477.8             NaN             NaN       CHARROULES
# ...                 ...             ...             ...              ...
# 170344         130000.0             1.0               A          GARENNE
# 170345         130000.0             NaN             NaN          GARENNE
# 170346           7500.0             NaN             NaN  PRAT DEL BAROUN
# 170347           7500.0             NaN             NaN  PRAT DEL BAROUN
# 170348           7500.0             NaN             NaN  PRAT DEL BAROUN
#
#        adresse_code_voie  code_postal  ...  type_local surface_reelle_bati  \
# 0                   0026      31790.0  ...      Maison               125.0
# 1                   B028      31790.0  ...         NaN                 NaN
# 2                   B002      31790.0  ...         NaN                 NaN
# 3                   B009      31790.0  ...         NaN                 NaN
# 4                   B009      31790.0  ...         NaN                 NaN
# ...                  ...          ...  ...         ...                 ...
# 170344              B020      31260.0  ...      Maison                85.0
# 170345              B020      31260.0  ...         NaN                 NaN
# 170346              B053      31260.0  ...         NaN                 NaN
# 170347              B053      31260.0  ...         NaN                 NaN
# 170348              B053      31260.0  ...         NaN                 NaN
#
#         nombre_pieces_principales  code_nature_culture  nature_culture  \
# 0                             5.0                    S            sols
# 1                             NaN                    S            sols
# 2                             NaN                    T          terres
# 3                             NaN                    T          terres
# 4                             NaN                    T          terres
# ...                           ...                  ...             ...
# 170344                        3.0                    S            sols
# 170345                        NaN                    T          terres
# 170346                        NaN                    S            sols
# 170347                        NaN                    P            prés
# 170348                        NaN                    P            prés
#
#        code_nature_culture_speciale  nature_culture_speciale  surface_terrain  \
# 0                               NaN                      NaN            482.0
# 1                               NaN                      NaN             54.0
# 2                               NaN                      NaN         194480.0
# 3                               NaN                      NaN          23724.0
# 4                               NaN                      NaN          10012.0
# ...                             ...                      ...              ...
# 170344                          NaN                      NaN             91.0
# 170345                          NaN                      NaN            197.0
# 170346                          NaN                      NaN             48.0
# 170347                          NaN                      NaN           4087.0
# 170348                          NaN                      NaN          12651.0
#
#         longitude   latitude
# 0        1.400431  43.750158
# 1        1.400366  43.750246
# 2        1.388276  43.736761
# 3        1.390008  43.739678
# 4        1.393089  43.736655
# ...           ...        ...
# 170344   1.021133  43.114045
# 170345   1.021415  43.114240
# 170346   1.024223  43.105863
# 170347   1.024139  43.105086
# 170348   1.023795  43.105634
#
# [170349 rows x 40 columns]

# %%
df = df[(df.type_local=="Maison")|(df.type_local=="Appartement")].reset_index()

# %%
df = df[df.nature_mutation=='Vente']

# %%
len(df)
# Out:
# 43199

# %%
df = df.drop_duplicates(subset=['id_mutation'])

# %%
df = df[['date_mutation','valeur_fonciere','code_postal','nom_commune','type_local','surface_reelle_bati','nombre_pieces_principales','nature_culture','surface_terrain']]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#       date_mutation  valeur_fonciere  code_postal    nom_commune   type_local  \
# 0        2022-01-13         315000.0      31790.0  Saint-Sauveur       Maison
# 1        2022-03-23         409670.0      31790.0  Saint-Sauveur       Maison
# 2        2022-04-26         357350.0      31790.0  Saint-Sauveur       Maison
# 3        2022-05-09         353300.0      31790.0  Saint-Sauveur       Maison
# 4        2022-05-11         500000.0      31790.0  Saint-Sauveur       Maison
# ...             ...              ...          ...            ...          ...
# 43194    2022-12-27          98000.0      31600.0         Eaunes  Appartement
# 43195    2023-04-04          70000.0      31260.0       Escoulis       Maison
# 43196    2023-08-01         240000.0      31260.0       Escoulis       Maison
# 43197    2023-09-29         121720.0      31260.0       Escoulis       Maison
# 43198    2023-11-02         130000.0      31260.0       Escoulis       Maison
#
#        surface_reelle_bati  nombre_pieces_principales       nature_culture  \
# 0                    125.0                        5.0                 sols
# 1                    160.0                        4.0                 sols
# 2                    158.0                        6.0                 sols
# 3                    114.0                        5.0                 sols
# 4                    255.0                        5.0                 sols
# ...                    ...                        ...                  ...
# 43194                 37.0                        2.0                  NaN
# 43195                 67.0                        3.0                 sols
# 43196                120.0                        4.0  terrains d'agrément
# 43197                 78.0                        3.0                 sols
# 43198                 85.0                        3.0                 sols
#
#       nature_culture_speciale  surface_terrain
# 0                         NaN            482.0
# 1                         NaN           1161.0
# 2                         NaN           1095.0
# 3                         NaN            862.0
# 4                         NaN           1200.0
# ...                       ...              ...
# 43194                     NaN              NaN
# 43195                     NaN             60.0
# 43196                     NaN           5345.0
# 43197                     NaN            488.0
# 43198                     NaN             91.0
#
# [43199 rows x 10 columns]

# %%
#save version df final
df.to_csv("HouseApptPrice_Tls.csv",index=False)

# %% [markdown]
# ## cleaning

# %%
df = pd.read_csv("HouseApptPrice_Tls.csv")

# %%
df.date_mutation = pd.to_datetime(df.date_mutation)

# %%
df['year'] = df['date_mutation'].dt.year
df['month'] = df['date_mutation'].dt.month

# %%
df['code_postal'] = df['code_postal'].apply(str)
df['code_postal'] = df['code_postal'].str.split('.').str[0]

# %%
df = df.drop('date_mutation',axis=1)

# %%
# donnée manquante
def percent_missing(df):
    per_nan = 100*df.isnull().sum() /len(df)
    per_nan = per_nan[per_nan >0].sort_values()
    
    return per_nan

# %%
per_nan = percent_missing(df)
per_nan
# Out:
# surface_reelle_bati           0.002315
# nombre_pieces_principales     0.002315
# valeur_fonciere               0.062501
# nature_culture               56.408713
# surface_terrain              56.408713
# dtype: float64

# %%
df = df.dropna(subset=['valeur_fonciere','surface_reelle_bati','nombre_pieces_principales'])

# %%
per_nan = percent_missing(df)
per_nan
# Out:
# nature_culture     56.422135
# surface_terrain    56.422135
# dtype: float64

# %%
df['nature_culture'] = df['nature_culture'].fillna('None')
df['surface_terrain'] = df['surface_terrain'].fillna(0)

# %%
per_nan = percent_missing(df)
per_nan
# Out:
# Series([], dtype: float64)

# %%
# Séparer appartement et Maison
df_maison = df[df['type_local']=='Maison']
df_appt = df[df['type_local']=='Appartement']

# %%
df_maison.to_csv("HousePrice_Tls.csv",index=False)
df_appt.to_csv("ApptPrice_Tls.csv",index=False)

# %%
len(df_maison)
# Out:
# 19426

# %%
len(df_appt)
# Out:
# 23745

# %% [markdown]
# ## Working on Housing Price

# %%
df_house = pd.read_csv("HousePrice_Tls.csv")

# %%
df_house['valeur_fonciere'].describe()
# Out:
# count    1.942600e+04
# mean     3.171762e+05
# std      2.513668e+05
# min      1.000000e+00
# 25%      1.970000e+05
# 50%      2.805850e+05
# 75%      3.818928e+05
# max      1.392000e+07
# Name: valeur_fonciere, dtype: float64

# %%
df_house[df_house['valeur_fonciere'] < 10000]
# Out:
#        valeur_fonciere  code_postal            nom_commune type_local  \
# 118              100.0        31440                    Fos     Maison
# 213                1.0        31800       Saux-et-Pomarède     Maison
# 345             1000.0        31210       Gourdan-Polignan     Maison
# 405             2200.0        31110            Saint-Mamet     Maison
# 444                1.0        31360  Roquefort-sur-Garonne     Maison
# ...                ...          ...                    ...        ...
# 15246            700.0        31220  Montclar-de-Comminges     Maison
# 15317              1.0        31550           Cintegabelle     Maison
# 17697              1.0        31470              Saint-Lys     Maison
# 17843           1400.0        31430     Marignac-Lasclares     Maison
# 18482              1.0        31130                  Balma     Maison
#
#        surface_reelle_bati  nombre_pieces_principales    nature_culture  \
# 118                   68.0                        3.0              sols
# 213                   78.0                        4.0               NaN
# 345                   65.0                        4.0              sols
# 405                  102.0                        4.0               NaN
# 444                   58.0                        3.0              sols
# ...                    ...                        ...               ...
# 15246                123.0                        4.0              sols
# 15317                 95.0                        4.0              sols
# 17697                 90.0                        4.0  terrains a bâtir
# 17843                103.0                        3.0              sols
# 18482                 99.0                        5.0              sols
#
#        surface_terrain  year  month
# 118              167.0  2022      9
# 213                0.0  2023      9
# 345              272.0  2023      6
# 405                0.0  2023      6
# 444               82.0  2023      4
# ...                ...   ...    ...
# 15246           1125.0  2022      8
# 15317           1754.0  2023     12
# 17697            369.0  2022      8
# 17843           3500.0  2022      6
# 18482             72.0  2022      8
#
# [61 rows x 10 columns]

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_house['valeur_fonciere'])
plt.title('Boxplot des Prix des Maisons')
plt.xlabel('Prix des Maisons (€)')
plt.show()

# %% [markdown]
# #### distribution logarythme

# %%
df_house['log_valeur_fonciere'] = np.log1p(df_house['valeur_fonciere'])

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house['log_valeur_fonciere'], bins=50, kde=True)
plt.title('Distribution Logarithmique des Prix des Maisons')
plt.xlabel('Log(Prix des Maisons)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Outliers superieur

# %%
def find_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    IQR = q3-q1
    outliers=df[((df<(q1-1.5*IQR)) | (df>(q3 + 1.5*IQR)))]
    return outliers

# %%
outliers_views = pd.DataFrame(find_outliers(df_house['valeur_fonciere']))

# %%
outliers_views.min()
# Out:
# valeur_fonciere    659600.0
# dtype: float64

# %%
len(outliers_views)
# Out:
# 906

# %%
100*len(outliers_views)/len(df_house)
# Out:
# 4.663852568722331

# %%
df_house = df_house.drop(outliers_views.index)

# %% [markdown]
# #### Outlier inferieur

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house[df_house['valeur_fonciere'] < 50000]['valeur_fonciere'], bins=50, kde=True)
plt.title('Distribution des Prix des Maisons Inférieurs à 50 000 €')
plt.xlabel('Prix des Maisons (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
count_below_10000 = len(df_house[df_house['valeur_fonciere'] < 10000])
print(f"Nombre de ventes inférieures à 10 000 €: {count_below_10000}")
# Out:
# Nombre de ventes inférieures à 10 000 €: 61

# %%
# prix moyenne au m² (mai 2024) Hautegaronne 2803euros (maison)

# %%
df_house['prix_mcarre'] = df_house['valeur_fonciere']/df_house['surface_reelle_bati']

# %%
df_house['prix_mcarre'].describe()
# Out:
# count    18520.000000
# mean      2821.901025
# std       1321.294418
# min          0.006452
# 25%       2046.153846
# 50%       2800.000000
# 75%       3444.586054
# max      31250.000000
# Name: prix_mcarre, dtype: float64

# %%
df_house.sort_values('prix_mcarre',ascending=False).iloc[0]
# Out:
# valeur_fonciere               500000.0
# code_postal                      31500
# nom_commune                   Toulouse
# type_local                      Maison
# surface_reelle_bati               16.0
# nombre_pieces_principales          1.0
# nature_culture                    sols
# surface_terrain                  337.0
# year                              2023
# month                               10
# log_valeur_fonciere          13.122365
# prix_mcarre                    31250.0
# cluster                              0
# Name: 16685, dtype: object

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house['prix_mcarre'], bins=100, kde=True)
plt.title('Distribution des Prix au metre carre')
plt.xlabel('Prix Au Metre Carre des Maisons (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
outliers = pd.DataFrame(find_outliers(df_house['prix_mcarre']))

# %%
len(outliers)
# Out:
# 503

# %%
100*len(outliers)/len(df_house)
# Out:
# 2.7159827213822894

# %%
df_house = df_house.drop(outliers.index)

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house['prix_mcarre'], bins=100, kde=True)
plt.title('Distribution des Prix au metre carre')
plt.xlabel('Prix Au Metre Carre des Maisons (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house['valeur_fonciere'], bins=100, kde=True)
plt.title('Distribution des Prix au metre carre')
plt.xlabel('Prix Au Metre Carre des Maisons (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# La maison la moins chere trouvé : aubusson : milieu diagonal du vide : 490euros/m² ... bengalow en camping 409euros/metre carré (et pas au bord de la mer)!
df_house[df_house['prix_mcarre'] < 500]['prix_mcarre'].describe()
# Out:
# count    321.000000
# mean     277.516164
# std      156.283360
# min        0.006452
# 25%      156.250000
# 50%      307.142857
# 75%      411.500000
# max      497.537313
# Name: prix_mcarre, dtype: float64

# %%
# La maison la moins chere trouvé : aubusson : milieu diagonal du vide : 490euros/m² 
plt.figure(figsize=(12, 6))
sns.histplot(df_house[df_house['prix_mcarre'] < 1100]['prix_mcarre'], bins=100, kde=True)
plt.title('Distribution des Prix metre carre des Maisons Inférieurs à 1000 €')
plt.xlabel('Prix des Maisons au metre carré (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_house = df_house[df_house['prix_mcarre'] >= 400]

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_house['valeur_fonciere'], bins=100, kde=True)
plt.title('Distribution des Prix au metre carre')
plt.xlabel('Prix Au Metre Carre des Maisons (€)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\Users\melan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Clustering ?

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=5000, min_samples=5).fit(df_house[['valeur_fonciere']].values)
labels = db.labels_

# %%
df_house['cluster'] = labels

# %%
outliers = df_house[df_house['cluster'] == -1]
print(outliers[['valeur_fonciere', 'surface_reelle_bati', 'surface_terrain', 'nombre_pieces_principales']])
# Out:
# Empty DataFrame
# Columns: [valeur_fonciere, surface_reelle_bati, surface_terrain, nombre_pieces_principales]
# Index: []

# %%
len(df_house[df_house['cluster'] ==0])
# Out:
# 18017

# %%
df_house = df_house.drop('cluster',axis=1)

# %% [markdown]
# ### EDA

# %%
df_house['valeur_fonciere'].describe()
# Out:
# count     17792.000000
# mean     282025.176895
# std      125558.820789
# min        9000.000000
# 25%      192000.000000
# 50%      272000.000000
# 75%      358500.000000
# max      658700.000000
# Name: valeur_fonciere, dtype: float64

# %%
df_house['prix_mcarre'].describe()
# Out:
# count    17792.000000
# mean      2733.773210
# std       1013.090522
# min        400.000000
# 25%       2057.055256
# 50%       2780.874406
# 75%       3395.375264
# max       5541.666667
# Name: prix_mcarre, dtype: float64

# %% [markdown]
# ### Outliers

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

sns.scatterplot(data=df_house, x='valeur_fonciere', y='surface_reelle_bati', ax=axes[0])
axes[0].set_title('Valeur Fonciere vs Surface Réelle Bâtie')
axes[0].axhline(y=400,color='green',linestyle='--')

sns.scatterplot(data=df_house, x='valeur_fonciere', y='surface_terrain', ax=axes[1])
axes[1].set_title('Valeur Fonciere vs Surface Terrain')
axes[1].axhline(y=13000,color='green',linestyle='--')

sns.scatterplot(data=df_house, x='valeur_fonciere', y='nombre_pieces_principales', ax=axes[2])
axes[2].set_title('Valeur Fonciere vs Nombre de Pièces Principales')
axes[2].axhline(y=11.5,color='green',linestyle='--')

fig.suptitle('Analyse de la Valeur Fonciere', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.show()

# %%
drop_ind_bati = df_house[(df_house['surface_reelle_bati']>400)].index
drop_ind_terrain = df_house[(df_house['surface_terrain']>13000)].index
drop_ind_piece = df_house[(df_house['nombre_pieces_principales']>11.5)].index

drop_indices = drop_ind_bati.union(drop_ind_terrain).union(drop_ind_piece)

df_house_cleaned = df_house.drop(drop_indices,axis=0)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

sns.scatterplot(data=df_house_cleaned, x='valeur_fonciere', y='surface_reelle_bati', ax=axes[0])
axes[0].set_title('Valeur Fonciere vs Surface Réelle Bâtie')


sns.scatterplot(data=df_house_cleaned, x='valeur_fonciere', y='surface_terrain', ax=axes[1])
axes[1].set_title('Valeur Fonciere vs Surface Terrain')


sns.scatterplot(data=df_house_cleaned, x='valeur_fonciere', y='nombre_pieces_principales', ax=axes[2])
axes[2].set_title('Valeur Fonciere vs Nombre de Pièces Principales')


fig.suptitle('Analyse de la Valeur Fonciere without outliers', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95]) 
plt.show()

# %%
df_house_cleaned.corr(numeric_only = True)['valeur_fonciere'].sort_values()
# Out:
# year                        -0.023503
# month                        0.004499
# code_postal                  0.036855
# surface_terrain              0.160364
# nombre_pieces_principales    0.441561
# surface_reelle_bati          0.510177
# prix_mcarre                  0.711411
# log_valeur_fonciere          0.934787
# valeur_fonciere              1.000000
# Name: valeur_fonciere, dtype: float64

# %%
corr = df_house_cleaned.corr(numeric_only = True)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_56aff_row0_col0, #T_56aff_row1_col1, #T_56aff_row2_col2, #T_56aff_row3_col3, #T_56aff_row4_col4, #T_56aff_row5_col5, #T_56aff_row6_col6, #T_56aff_row7_col7, #T_56aff_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col1, #T_56aff_row3_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_56aff_row0_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_56aff_row0_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col5, #T_56aff_row5_col6, #T_56aff_row6_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col6, #T_56aff_row1_col6, #T_56aff_row4_col5, #T_56aff_row7_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col7, #T_56aff_row7_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_56aff_row0_col8 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_56aff_row1_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col5, #T_56aff_row6_col3, #T_56aff_row6_col4, #T_56aff_row6_col7, #T_56aff_row8_col5, #T_56aff_row8_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_56aff_row1_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_56aff_row2_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_56aff_row2_col1, #T_56aff_row5_col4, #T_56aff_row6_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_56aff_row2_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_56aff_row2_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_56aff_row2_col5, #T_56aff_row2_col6, #T_56aff_row2_col8, #T_56aff_row3_col5, #T_56aff_row4_col6, #T_56aff_row5_col0, #T_56aff_row5_col1, #T_56aff_row5_col3, #T_56aff_row5_col7, #T_56aff_row8_col2, #T_56aff_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_56aff_row2_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_56aff_row3_col0, #T_56aff_row7_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_56aff_row3_col2, #T_56aff_row8_col0 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_56aff_row3_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_56aff_row3_col6, #T_56aff_row7_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_56aff_row3_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_56aff_row3_col8, #T_56aff_row5_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_56aff_row4_col0, #T_56aff_row7_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_56aff_row4_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_56aff_row4_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_56aff_row4_col3, #T_56aff_row4_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_56aff_row4_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_56aff_row5_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_56aff_row6_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_56aff_row6_col5, #T_56aff_row8_col1, #T_56aff_row8_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_56aff_row6_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_56aff_row7_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_56aff_row7_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_56aff_row7_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_56aff_row8_col7 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# </style>
# <table id="T_56aff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56aff_level0_col0" class="col_heading level0 col0" >valeur_fonciere</th>
#       <th id="T_56aff_level0_col1" class="col_heading level0 col1" >code_postal</th>
#       <th id="T_56aff_level0_col2" class="col_heading level0 col2" >surface_reelle_bati</th>
#       <th id="T_56aff_level0_col3" class="col_heading level0 col3" >nombre_pieces_principales</th>
#       <th id="T_56aff_level0_col4" class="col_heading level0 col4" >surface_terrain</th>
#       <th id="T_56aff_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_56aff_level0_col6" class="col_heading level0 col6" >month</th>
#       <th id="T_56aff_level0_col7" class="col_heading level0 col7" >log_valeur_fonciere</th>
#       <th id="T_56aff_level0_col8" class="col_heading level0 col8" >prix_mcarre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56aff_level0_row0" class="row_heading level0 row0" >valeur_fonciere</th>
#       <td id="T_56aff_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_56aff_row0_col1" class="data row0 col1" >0.036855</td>
#       <td id="T_56aff_row0_col2" class="data row0 col2" >0.510177</td>
#       <td id="T_56aff_row0_col3" class="data row0 col3" >0.441561</td>
#       <td id="T_56aff_row0_col4" class="data row0 col4" >0.160364</td>
#       <td id="T_56aff_row0_col5" class="data row0 col5" >-0.023503</td>
#       <td id="T_56aff_row0_col6" class="data row0 col6" >0.004499</td>
#       <td id="T_56aff_row0_col7" class="data row0 col7" >0.934787</td>
#       <td id="T_56aff_row0_col8" class="data row0 col8" >0.711411</td>
#     </tr>
#     <tr>
#       <th id="T_56aff_level0_row1" class="row_heading level0 row1" >code_postal</th>
#       <td id="T_56aff_row1_col0" class="data row1 col0" >0.036855</td>
#       <td id="T_56aff_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_56aff_row1_col2" class="data row1 col2" >0.027722</td>
#       <td id="T_56aff_row1_col3" class="data row1 col3" >0.039358</td>
#       <td id="T_56aff_row1_col4" class="data row1 col4" >0.045067</td>
#       <td id="T_56aff_row1_col5" class="data row1 col5" >-0.002921</td>
#       <td id="T_56aff_row1_col6" class="data row1 col6" >0.002325</td>
#       <td id="T_56aff_row1_col7" class="data row1 col7" >0.052531</td>
#       <td id="T_56aff_row1_col8" class="data row1 col8" >0.018404</td>
#     </tr>
#     <tr>
#       <th id="T_56aff_level0_row2" class="row_heading level0 row2" >surface_reelle_bati</th>
#       <td id="T_56aff_row2_col0" class="data row2 col0" >0.510177</td>
#       <td id="T_56aff_row2_col1" class="data row2 col1" >0.027722</td>
#       <td id="T_56aff_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_56aff_row2_col3" class="data row2 col3" >0.668417</td>
#       <td id="T_56aff_row2_col4" class="data row2 col4" >0.285074</td>
#       <td id="T_56aff_row2_col5" class="data row2 col5" >-0.029083</td>
#       <td id="T_56aff_row2_col6" class="data row2 col6" >-0.011566</td>
#       <td id="T_56aff_row2_col7" class="data row2 col7" >0.458510</td>
#       <td id="T_56aff_row2_col8" class="data row2 col8" >-0.167425</td>
#     </tr>
#     <tr>
#       <th id="T_56aff_level0_row3" class="row_heading level0 row3" >nombre_pieces_principales</th>
#       <td id="T_56aff_row3_col0" class="data row3 col0" >0.441561</td>
#       <td id="T_56aff_row3_col1" class="data row3 col1" >0.039358</td>
#       <td id="T_56aff_row3_col2" class="data row3 col2" >0.668417</td>
#       <td id="T_56aff_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_56aff_row3_col4" class="data row3 col4" >0.135516</td>
#       <td id="T_56aff_row3_col5" class="data row3 col5" >-0.030966</td>
#       <td id="T_56aff_row3_col6" class="data row3 col6" >-0.003974</td>
#       <td id="T_56aff_row3_col7" class="data row3 col7" >0.438198</td>
#       <td id="T_56aff_row3_col8" class="data row3 col8" >-0.007073</td>
#     </tr>
#     <tr>
#       <th id="T_56aff_level0_row4" class="row_heading level0 row4" >surface_terrain</th>
#       <td id="T_56aff_row4_col0" class="data row4 col0" >0.160364</td>
#       <td id="T_56aff_row4_col1" class="data row4 col1" >0.045067</td>
#       <td id="T_56aff_row4_col2" class="data row4 col2" >0.285074</td>
#       <td id="T_56aff_row4_col3" class="data row4 col3" >0.135516</td>

# %%
df_house_cleaned.to_csv('HousePrice_no_outliers.csv',index=False)

# %% [markdown]
# ### Filtering by postal code

# %%
df_house = pd.read_csv('HousePrice_no_outliers.csv')

# %%
df_house
# Out:
#        valeur_fonciere  code_postal    nom_commune type_local  \
# 0             315000.0        31790  Saint-Sauveur     Maison
# 1             409670.0        31790  Saint-Sauveur     Maison
# 2             357350.0        31790  Saint-Sauveur     Maison
# 3             353300.0        31790  Saint-Sauveur     Maison
# 4             500000.0        31790  Saint-Sauveur     Maison
# ...                ...          ...            ...        ...
# 17748         140000.0        31600         Eaunes     Maison
# 17749          70000.0        31260       Escoulis     Maison
# 17750         240000.0        31260       Escoulis     Maison
# 17751         121720.0        31260       Escoulis     Maison
# 17752         130000.0        31260       Escoulis     Maison
#
#        surface_reelle_bati  nombre_pieces_principales       nature_culture  \
# 0                    125.0                        5.0                 sols
# 1                    160.0                        4.0                 sols
# 2                    158.0                        6.0                 sols
# 3                    114.0                        5.0                 sols
# 4                    255.0                        5.0                 sols
# ...                    ...                        ...                  ...
# 17748                 70.0                        3.0                 sols
# 17749                 67.0                        3.0                 sols
# 17750                120.0                        4.0  terrains d'agrément
# 17751                 78.0                        3.0                 sols
# 17752                 85.0                        3.0                 sols
#
#        surface_terrain  year  month  log_valeur_fonciere  prix_mcarre
# 0                482.0  2022      1            12.660331  2520.000000
# 1               1161.0  2022      3            12.923110  2560.437500
# 2               1095.0  2022      4            12.786474  2261.708861
# 3                862.0  2022      5            12.775076  3099.122807
# 4               1200.0  2022      5            13.122365  1960.784314
# ...                ...   ...    ...                  ...          ...
# 17748            322.0  2022     12            11.849405  2000.000000
# 17749             60.0  2023      4            11.156265  1044.776119
# 17750           5345.0  2023      8            12.388398  2000.000000
# 17751            488.0  2023      9            11.709487  1560.512821
# 17752             91.0  2023     11            11.775297  1529.411765
#
# [17753 rows x 12 columns]

# %%
df_house['code_postal'].value_counts()
# Out:
# code_postal
# 31600    870
# 31470    610
# 31700    609
# 31100    567
# 31140    550
#         ...
# 31850     65
# 31280     65
# 31580     54
# 31670     34
# 31000     25
# Name: count, Length: 70, dtype: int64

# %%
#ex:
df_house_31600 = df_house[df_house['code_postal'] == 31600]

# %%
sns.scatterplot(data=df_house_31600, x='surface_reelle_bati',y='valeur_fonciere')
# Out:
# <Axes: xlabel='surface_reelle_bati', ylabel='valeur_fonciere'>

# %%
def calculate_correlation(group):
    return group['valeur_fonciere'].corr(group['surface_reelle_bati'])

# %%
correlation_by_postal_code = df_house.groupby('code_postal').apply(calculate_correlation)

for code_postal, correlation in correlation_by_postal_code.items():
    if correlation >= 0.6:
        print(f'Code Postal: {code_postal}, Corrélation: {correlation:.2f}')
# Out:
# Code Postal: 31000, Corrélation: 0.73
# Code Postal: 31100, Corrélation: 0.63
# Code Postal: 31110, Corrélation: 0.60
# Code Postal: 31120, Corrélation: 0.67
# Code Postal: 31130, Corrélation: 0.63
# Code Postal: 31140, Corrélation: 0.67
# Code Postal: 31150, Corrélation: 0.65
# Code Postal: 31160, Corrélation: 0.62
# Code Postal: 31170, Corrélation: 0.73
# Code Postal: 31180, Corrélation: 0.69
# Code Postal: 31190, Corrélation: 0.61
# Code Postal: 31200, Corrélation: 0.66
# Code Postal: 31240, Corrélation: 0.63
# Code Postal: 31270, Corrélation: 0.67
# Code Postal: 31290, Corrélation: 0.64
# Code Postal: 31300, Corrélation: 0.66
# Code Postal: 31320, Corrélation: 0.66
# Code Postal: 31340, Corrélation: 0.61
# Code Postal: 31380, Corrélation: 0.64
# Code Postal: 31400, Corrélation: 0.61
# Code Postal: 31460, Corrélation: 0.63
# Code Postal: 31470, Corrélation: 0.67
# Code Postal: 31490, Corrélation: 0.67
# Code Postal: 31500, Corrélation: 0.70
# Code Postal: 31510, Corrélation: 0.67
# Code Postal: 31520, Corrélation: 0.74
# Code Postal: 31530, Corrélation: 0.63
# Code Postal: 31540, Corrélation: 0.66
# Code Postal: 31560, Corrélation: 0.66
# Code Postal: 31580, Corrélation: 0.61
# Code Postal: 31600, Corrélation: 0.64
# Code Postal: 31650, Corrélation: 0.68
# Code Postal: 31660, Corrélation: 0.66
# Code Postal: 31670, Corrélation: 0.67
# Code Postal: 31700, Corrélation: 0.65
# Code Postal: 31750, Corrélation: 0.68
# Code Postal: 31770, Corrélation: 0.67
# Code Postal: 31800, Corrélation: 0.66
# Code Postal: 31820, Corrélation: 0.76
# Code Postal: 31830, Corrélation: 0.68
# Code Postal: 31840, Corrélation: 0.65
# Code Postal: 31850, Corrélation: 0.74
# Code Postal: 31860, Corrélation: 0.62
# Code Postal: 31870, Corrélation: 0.71

# %%
correlation_by_postal_code = df_house.groupby('code_postal').apply(calculate_correlation)

for code_postal, correlation in correlation_by_postal_code.items():
    if correlation < 0.6:
        print(f'Code Postal: {code_postal}, Corrélation: {correlation:.2f}')
# Out:
# Code Postal: 31210, Corrélation: 0.60
# Code Postal: 31220, Corrélation: 0.56
# Code Postal: 31230, Corrélation: 0.59
# Code Postal: 31250, Corrélation: 0.54
# Code Postal: 31260, Corrélation: 0.51
# Code Postal: 31280, Corrélation: 0.43
# Code Postal: 31310, Corrélation: 0.55
# Code Postal: 31330, Corrélation: 0.54
# Code Postal: 31350, Corrélation: 0.55
# Code Postal: 31360, Corrélation: 0.53
# Code Postal: 31370, Corrélation: 0.52
# Code Postal: 31390, Corrélation: 0.53
# Code Postal: 31410, Corrélation: 0.59
# Code Postal: 31420, Corrélation: 0.54
# Code Postal: 31430, Corrélation: 0.51
# Code Postal: 31440, Corrélation: 0.60
# Code Postal: 31450, Corrélation: 0.60
# Code Postal: 31480, Corrélation: 0.43
# Code Postal: 31550, Corrélation: 0.51
# Code Postal: 31570, Corrélation: 0.50
# Code Postal: 31590, Corrélation: 0.44
# Code Postal: 31620, Corrélation: 0.56
# Code Postal: 31780, Corrélation: 0.57
# Code Postal: 31790, Corrélation: 0.58
# Code Postal: 31810, Corrélation: 0.51
# Code Postal: 31880, Corrélation: 0.60

# %%
correlation_by_postal_code = df_house.groupby('code_postal').apply(calculate_correlation)

for code_postal, correlation in correlation_by_postal_code.items():
    if correlation < 0.5:
        print(f'Code Postal: {code_postal}, Corrélation: {correlation:.2f}')
# Out:
# Code Postal: 31280, Corrélation: 0.43
# Code Postal: 31480, Corrélation: 0.43
# Code Postal: 31570, Corrélation: 0.50
# Code Postal: 31590, Corrélation: 0.44

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data = df_house,y='valeur_fonciere', x='year')
plt.title('Distribution des Prix par année')

plt.show()

# %%
df_house[df_house['year']==2022]['valeur_fonciere'].mean()
# Out:
# 284395.3989456837

# %%
df_house[df_house['year']==2023]['valeur_fonciere'].mean()
# Out:
# 278453.0628300671

# %%
import scipy.stats as stats

# %%
X1 = df_house[df_house['year']==2022]['valeur_fonciere']

# %%
X2 = df_house[df_house['year']==2023]['valeur_fonciere']

# %%
stats.ttest_ind(X1,X2)
# Out:
# TtestResult(statistic=3.132270807678287, pvalue=0.0017374172030405913, df=17751.0)

# %%
# Dernier truc a faire FE :

# %%
# Type colonne object (categorie): Year,Codepostale,

# %%
# ou l'entrainer sur log ou sur valeur fonciere clean : suppr metre carré/ +log ou valeur fonciere (tester les 2 ?)/ supprimer month ?

# %%
#dummies categorie (codepostale, year, ...)

# %%
#modele regression lineaire (ElastiqueNet puis Lasso ou autre...)

# %% [markdown]
# ## Working on appt Price

# %%
df = pd.read_csv("ApptPrice_Tls.csv")
